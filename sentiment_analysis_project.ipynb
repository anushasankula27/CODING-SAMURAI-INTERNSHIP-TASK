# %%
import pandas as pd
import matplotlib.pyplot as plt
from textblob import TextBlob

# %%
data = {
    "Text": [
        "I love this product!",
        "This is the worst service ever",
        "The movie was okay, not bad",
        "Amazing experience, very happy",
        "I am disappointed with the quality",
        "It is an average performance"
    ]
}

df = pd.DataFrame(data)
print(df)
# Out:
#                                  Text
# 0                I love this product!
# 1      This is the worst service ever
# 2         The movie was okay, not bad
# 3      Amazing experience, very happy
# 4  I am disappointed with the quality
# 5        It is an average performance

# %%
def get_polarity(text):
    return TextBlob(text).sentiment.polarity

df["Polarity"] = df["Text"].apply(get_polarity)
print(df)
# Out:
#                                  Text  Polarity
# 0                I love this product!     0.625
# 1      This is the worst service ever    -1.000
# 2         The movie was okay, not bad     0.425
# 3      Amazing experience, very happy     0.800
# 4  I am disappointed with the quality    -0.750
# 5        It is an average performance    -0.150

# %%
def get_sentiment(score):
    if score > 0:
        return "Positive"
    elif score < 0:
        return "Negative"
    else:
        return "Neutral"

df["Sentiment"] = df["Polarity"].apply(get_sentiment)
print(df)
# Out:
#                                  Text  Polarity Sentiment
# 0                I love this product!     0.625  Positive
# 1      This is the worst service ever    -1.000  Negative
# 2         The movie was okay, not bad     0.425  Positive
# 3      Amazing experience, very happy     0.800  Positive
# 4  I am disappointed with the quality    -0.750  Negative
# 5        It is an average performance    -0.150  Negative

# %%
sentiment_counts = df["Sentiment"].value_counts()
print(sentiment_counts)
# Out:
# Sentiment
# Positive    3
# Negative    3
# Name: count, dtype: int64

# %%
sentiment_counts.plot(kind='bar')
plt.xlabel("Sentiment")
plt.ylabel("Number of Posts")
plt.title("Social Media Sentiment Analysis")
plt.show()

# %%
df.to_csv("sentiment_analysis_results.csv", index=False)
print("Results saved successfully!")
# Out:
# Results saved successfully!
